# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original DataFrame with NaN
#          one       two     three
# a -0.718394  1.287132  0.823016
# b       NaN       NaN       NaN
# c -0.698062 -0.381520 -0.322433
# d -1.443136 -0.011020 -1.144038
# e       NaN       NaN       NaN
# f  3.154011 -0.270442  0.925363
#
#
# Dropped DataFrame
#          one       two     three
# a -0.718394  1.287132  0.823016
# c -0.698062 -0.381520 -0.322433
# d -1.443136 -0.011020 -1.144038
# f  3.154011 -0.270442  0.925363

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\n")
print("NaN replaced with '0'\n")
print(df.fillna(0))
# Out:
# Original DataFrame:
#          one       two     three
# a -1.210622  0.613178 -1.518837
# b       NaN       NaN       NaN
# c  0.515407 -0.010906  0.029659
# d  1.108220 -0.423352  0.092901
# e       NaN       NaN       NaN
# f -1.243171 -0.216920 -1.072265
#
#
# NaN replaced with '0'
#
#         one       two     three
# a -1.210622  0.613178 -1.518837
# b  0.000000  0.000000  0.000000
# c  0.515407 -0.010906  0.029659
# d  1.108220 -0.423352  0.092901
# e  0.000000  0.000000  0.000000
# f -1.243171 -0.216920 -1.072265

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original DataFrame:
#          one       two     three
# a -0.898295  0.461607  1.148857
# b       NaN       NaN       NaN
# c -0.258431 -0.994896  0.448088
# d -0.214139 -1.050384 -0.213429
# e       NaN       NaN       NaN
# f -0.978150 -0.107241  0.449078
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNan-Filled with the Background value:\n")
print(df.fillna(method='bfill'))
# Out:
# Original DataFrame:
#          one       two     three
# a  0.894447  2.685597  0.611504
# b       NaN       NaN       NaN
# c -2.809409 -0.829055  0.009613
# d  0.299419 -1.737006 -1.097055
# e       NaN       NaN       NaN
# f -0.149796  0.048556  0.787513
#
# Nan-Filled with the Background value:
#
#         one       two     three
# a  0.894447  2.685597  0.611504
# b -2.809409 -0.829055  0.009613
# c -2.809409 -0.829055  0.009613
# d  0.299419 -1.737006 -1.097055
# e -0.149796  0.048556  0.787513
# f -0.149796  0.048556  0.787513
